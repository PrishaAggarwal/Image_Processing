# %% [markdown]
# pixel is peice of information...more number of pixels and hence more information <br>
# we need visualization for capturing and visualizing <br>
# our eyes and camera are sensitive to photons <br>
#
# diff between resolution and pixels <br>
# and 48 megapixels takes 10 mb and 50 megapixels takes 25 mb <br>
# why so much diff ? <br>
#
# convert to gray scale or binary taki storing easy ho and retrival easy ho and sometimes image se itni information ki no need <br>
# coloured mein 3 axis and ek pixel...kbhi kidhr kabhi kidhr toh alot of information  <br>
# gray mein ek axis bas <br>
# toh less info <br>
# toh iskiye kaam kam oska and storage <br>
#
# we can never add information to an image....only retrieve Nd agar we put thats perceived and not actually there <br>
# u can add info only if tum osko exactly replicate kro and recapture kro <br>
#
# ques 1 : convert coloured image to binary directly withouit converting into gray scale in between <br>
# ques 2 : display all images side by side.....ek grid mein matplotlib.pylot use krke ek grid mein krdo <br>
# ques 3 : also max intensity try with diff value and check diff <br>
# ques 4 : bgr to gray mein i am show ki jagah ...try nd display image with matplotlib and see if there is diff..hence matplotlib has some variations <br>
# ques 5 : image resize krke dekho <br>
# ques 6 : and size dekhna on changing from coloured to binary....then size diff dekho <br>
#
# Implement all the above ques
#
# when vapis we were converting hume same image wali coloured image nhi milli...hence we cant put things into image <br>
